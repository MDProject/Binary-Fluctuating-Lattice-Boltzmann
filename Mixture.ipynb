# %%
def format_params(number, precision=2, exponent_digits=2):
    # Format the number in scientific notation
    scientific = f"{number:.{precision}e}"
    # Split into base and exponent
    base, exponent = scientific.split("e")
    # Reformat the exponent with leading zeros
    exponent = int(exponent)  # Convert to integer
    formatted_exponent = f"e{'+' if exponent >= 0 else '-'}{abs(exponent):0{exponent_digits}d}"
    return f"{base}{formatted_exponent}"

#format_params(temperature, 0, 1)
'''
find ./data_mixture/ -type d -name "plt2000410"
 du -sh <folder dir>    #   check folder size
'''
# Out:
# '\nfind ./data_mixture/ -type d -name "plt2000410"\n du -sh <folder dir>    #   check folder size\n'

# %% [markdown]
# $$v=\frac{3}{4}\overline{v}+\frac{1}{4}\overline{v}^{\prime}+\frac{1}{2}\overline{\xi},\ \ v^{\prime}=\frac{3}{4}\overline{v}^{\prime}+\frac{1}{4}\overline{v}-\frac{1}{2}\overline{\xi}$$
#
# $$\begin{aligned}
# 	\left\langle v,v^{\prime}\right\rangle &=\left\langle \frac{3}{4}\overline{v}+\frac{1}{4}\overline{v}^{\prime}+\frac{1}{2}\overline{\xi},\frac{3}{4}\overline{v}^{\prime}+\frac{1}{4}\overline{v}-\frac{1}{2}\overline{\xi}\right\rangle \\
# 	&=\frac{9}{16}\left\langle \overline{v},\overline{v}^{\prime}\right\rangle +\frac{3}{16}\left\langle \overline{v},\overline{v}\right\rangle +\frac{3}{16}\left\langle \overline{v}^{\prime},\overline{v}^{\prime}\right\rangle +\frac{1}{16}\left\langle \overline{v}^{\prime},\overline{v}\right\rangle -\frac{1}{4}\left\langle \overline{\xi},\overline{\xi}\right\rangle \\
# 	&=\frac{3}{8}\left\langle \overline{v},\overline{v}\right\rangle -\frac{1}{4}\left\langle \overline{\xi},\overline{\xi}\right\rangle
#   \end{aligned}$$

# %%
import yt
from matplotlib import rc_context
from matplotlib.animation import FuncAnimation
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 20,           # General font size
    'axes.titlesize': 20,      # Axes title
    'axes.labelsize': 20,      # Axes labels
    'xtick.labelsize': 18,     # X-axis tick labels
    'ytick.labelsize': 18,     # Y-axis tick labels
    'legend.fontsize': 16,     # Legend
    'figure.titlesize': 18     # Figure title
})
print(yt.__version__)

############    modify if needed    ############################
step1 = 410
step_SF = 600500
temperature = 1e-5
alpha0 = 0.
cs2 = 1./3.
nx = 32#64
ny = 32#2
nz = 32#2
suffix = "hydrovars"
#######################################################
pltfiledir = "./data_mixture_" + suffix
plot_file_dir_SF_mag = pltfiledir + "/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}_continue/plt_SF_mag00".format(nx,ny,nz) +\
              f"{step_SF:07d}" # total 9 digits number for step info 
plot_file_dir_SF_real_imag = "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}_continue/plt_SF_real_imag00".format(nx,ny,nz) +\
              f"{step_SF:07d}"
print(plot_file_dir_SF_mag)
ds = yt.load(plot_file_dir_SF_mag)
print(ds.field_list)
#profile_data = ds.all_data()[("boxlib", "struct_fact_rho_rho")].to_ndarray()
profile_data = ds.covering_grid(
    level=0, left_edge=ds.domain_left_edge, dims=ds.domain_dimensions
)
S_rho_FHDeX = profile_data["boxlib", "struct_fact_rho_rho"] # magnitude
S_phi_FHDeX = profile_data["boxlib", "struct_fact_phi_phi"] # magnitude
S_ufx_FHDeX = profile_data["boxlib", "struct_fact_ufx_ufx"] # magnitude
S_ufy_FHDeX = profile_data["boxlib", "struct_fact_ufy_ufy"] # magnitude 
S_ufz_FHDeX = profile_data["boxlib", "struct_fact_ufz_ufz"] # magnitude
S_ugx_FHDeX = profile_data["boxlib", "struct_fact_ugx_ugx"] # magnitude
S_ugy_FHDeX = profile_data["boxlib", "struct_fact_ugy_ugy"] # magnitude
S_ugz_FHDeX = profile_data["boxlib", "struct_fact_ugz_ugz"] # magnitude
S_ufx_ugx_FHDeX = profile_data["boxlib", "struct_fact_ugx_ufx"] # magnitude

#S_ufyx_FHDeX = profile_data["boxlib", "struct_fact_ufy_ufx"] # magnitude 
#S_afx_FHDeX = profile_data["boxlib", "struct_fact_afx_afx"] # magnitude 
#S_afy_FHDeX = profile_data["boxlib", "struct_fact_afy_afy"] # magnitude 
#S_afz_FHDeX = profile_data["boxlib", "struct_fact_afz_afz"] # magnitude 
S_ubx_FHDeX = profile_data["boxlib", "struct_fact_ubx_ubx"] # magnitude
S_uby_FHDeX = profile_data["boxlib", "struct_fact_uby_uby"] # magnitude
S_ubz_FHDeX = profile_data["boxlib", "struct_fact_ubz_ubz"] # magnitude

# modified velocity, also called LB velocity;
S_ufbarx_FHDeX = profile_data["boxlib", "struct_fact_ufbarx_ufbarx"] # magnitude
#S_ufbary_FHDeX = profile_data["boxlib", "struct_fact_ufbary_ufbary"] # magnitude
#S_ufbarz_FHDeX = profile_data["boxlib", "struct_fact_ufbarz_ufbarz"] # magnitude
S_ugbarx_FHDeX = profile_data["boxlib", "struct_fact_ugbarx_ugbarx"] # magnitude
#S_ugbary_FHDeX = profile_data["boxlib", "struct_fact_ugbary_ugbary"] # magnitude
#S_ugbarz_FHDeX = profile_data["boxlib", "struct_fact_ugbarz_ugbarz"] # magnitude
S_nfbarx_FHDeX = profile_data["boxlib", "struct_fact_nfbarx_nfbarx"] # magnitude
S_ngbarx_FHDeX = profile_data["boxlib", "struct_fact_ngbarx_ngbarx"] # magnitude

S_ufbarx_nfbarx_FHDeX = profile_data["boxlib", "struct_fact_nfbarx_ufbarx"] # magnitude
S_ufbarx_ugbarx_FHDeX = profile_data["boxlib", "struct_fact_ugbarx_ufbarx"] # magnitude
S_ugbarx_nfbarx_FHDeX = profile_data["boxlib", "struct_fact_nfbarx_ugbarx"] # magnitude

print((S_rho_FHDeX/(temperature/cs2)))

box = ds.domain_dimensions
nxh = box[0]//2
kx = 2*np.pi/box[0]*(np.linspace(0, nxh-1, nxh))
'''
S_rho_array_kx = np.mean(S_rho_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,:,:], axis=(1, 2))/(temperature/cs2)
S_phi_array_kx = np.mean(S_phi_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,:,:], axis=(1, 2))/(temperature/cs2)
S_ufx_array_kx = np.mean(S_ufx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,:,:], axis=(1, 2))/(temperature)
S_ufy_array_kx = np.mean(S_ufy_FHDeX[:,nxh%box[0]:(2*nxh-1)%box[0]+1,:], axis=(0, 2))/(temperature)
S_ufz_array_kx = np.mean(S_ufz_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,:,:], axis=(1, 2))/(temperature)
S_ufyx_array_kx = np.mean(S_ufyx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,:,:], axis=(1, 2))/(temperature)
S_ufzy_array_kx = np.mean(S_ufzy_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,:,:], axis=(1, 2))/(temperature)
'''
S_rho_array_kx = S_rho_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/cs2)
S_phi_array_kx = S_phi_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/cs2)
S_ufx_array_kx = S_ufx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)   # real hydrovars velocity
S_ufy_array_kx = S_ufy_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)   
S_ufz_array_kx = S_ufz_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)   
S_ugx_array_kx = S_ugx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)   # real hydrovars velocity
S_ugy_array_kx = S_ugy_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)
S_ugz_array_kx = S_ugz_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)

S_ubx_array_kx = S_ubx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/2.)
S_uby_array_kx = S_uby_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/2.)
S_ubz_array_kx = S_ubz_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/2.)
S_ufbarx_array_kx = S_ufbarx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature) # LB hydrovars velocity (modified velocity)
S_ugbarx_array_kx = S_ugbarx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature) # LB hydrovars velocity (modified velocity)
S_nfbarx_array_kx = S_nfbarx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)
S_ngbarx_array_kx = S_ngbarx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)
S_ufbarx_nfbarx_array_kx = S_ufbarx_nfbarx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)
S_ufbarx_ugbarx_array_kx = S_ufbarx_ugbarx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)
S_ugbarx_nfbarx_array_kx = S_ugbarx_nfbarx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)
S_ufx_ugx_array_kx = S_ufx_ugx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature) # modified velocity

plt.figure(1, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_rho_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel(r"$k_x$")  # X-axis label
plt.ylabel(r"$S_\rho$")  # Y-axis label
plt.title(r"$S_\rho$ vs $k_x$ $(\alpha_0={:.2f}), \; size=({:d},{:d},{:d})$".format(alpha0, nx, ny, nz))  # Plot title
plt.ylim(0,1.2)
plt.grid(True)
#plt.savefig('rho_f.png')  # You can use .png, .jpg, .pdf, .svg, etc.


plt.figure(2, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_phi_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S phi vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.2)
plt.grid(True)
#plt.savefig('rho_g.png')

plt.figure(3, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
#plt.savefig('ufx.png')

plt.figure(4, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufy_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufy vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
#plt.savefig('ufy.png')

plt.figure(5, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufz_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufz vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
#plt.savefig('ufz.png')

plt.figure(6, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ugx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ugx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)

plt.figure(7, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ugy_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ugy vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
# Show the plot
plt.show()

plt.figure(8, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ubx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ubx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
# Show the plot
plt.show()

plt.figure(9, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_uby_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S uby vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
# Show the plot
plt.show()

plt.figure(10, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufx_ugx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufx_ugx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
# Show the plot
plt.show()
#plt.savefig('my_plot.png', dpi=300)
# Out:
# yt : [INFO     ] 2025-09-01 17:58:00,670 Parameters: current_time              = 600500.0
# yt : [INFO     ] 2025-09-01 17:58:00,671 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-09-01 17:58:00,671 Parameters: domain_left_edge          = [-16.5 -16.5 -16.5]
# yt : [INFO     ] 2025-09-01 17:58:00,672 Parameters: domain_right_edge         = [15.5 15.5 15.5]
# 4.4.0
# ./data_mixture_hydrovars/lbm_data_shshan_alpha0_0.00_xi_1.0e-05_size32-32-32_continue/plt_SF_mag000600500
# [('boxlib', 'struct_fact_afx_afx'), ('boxlib', 'struct_fact_nfbarx_nfbarx'), ('boxlib', 'struct_fact_nfbarx_ufbarx'), ('boxlib', 'struct_fact_nfbarx_ugbarx'), ('boxlib', 'struct_fact_ngbarx_ngbarx'), ('boxlib', 'struct_fact_phi_phi'), ('boxlib', 'struct_fact_phi_rho'), ('boxlib', 'struct_fact_rho_rho'), ('boxlib', 'struct_fact_ubx_ubx'), ('boxlib', 'struct_fact_uby_ubx'), ('boxlib', 'struct_fact_uby_uby'), ('boxlib', 'struct_fact_ubz_ubz'), ('boxlib', 'struct_fact_ufbarx_ufbarx'), ('boxlib', 'struct_fact_ufx_ufx'), ('boxlib', 'struct_fact_ufy_ufy'), ('boxlib', 'struct_fact_ufz_ufz'), ('boxlib', 'struct_fact_ugbarx_ufbarx'), ('boxlib', 'struct_fact_ugbarx_ugbarx'), ('boxlib', 'struct_fact_ugx_ufx'), ('boxlib', 'struct_fact_ugx_ugx'), ('boxlib', 'struct_fact_ugy_ugy'), ('boxlib', 'struct_fact_ugz_ugz')]
# [[[0.94819509 1.00521874 0.99197593 ... 1.01710685 0.99197593 1.00521874]
#   [0.95723689 1.0015326  0.99292674 ... 1.0054068  1.03727108 0.96164665]
#   [1.04214636 0.99091806 1.00961383 ... 0.98747341 0.99161369 1.01354458]
#   ...
#   [0.98137611 0.98546818 0.94429602 ... 0.9630883  1.01133571 0.98886583]
#   [1.04214636 1.01354458 0.99161369 ... 1.00927506 1.00961383 0.99091806]
#   [0.95723689 0.96164665 1.03727108 ... 1.03922274 0.99292674 1.0015326 ]]
#
#  [[1.01598885 0.99841868 1.00399415 ... 0.98912297 1.01345623 0.981747  ]
#   [0.99680672 1.01854001 0.97508173 ... 1.0300159  1.01667582 1.00135148]
#   [1.0108995  0.93246254 0.97849204 ... 0.97904731 1.00477354 0.95454723]
#   ...
#   [1.02207472 0.98161966 1.02177124 ... 1.02565554 0.99207723 1.02886019]
#   [1.00170404 0.99763404 0.99335757 ... 1.00813312 0.97981913 0.97994453]
#   [1.00200145 0.98492376 0.97284631 ... 0.98877091 1.03613808 0.97942834]]
#
#  [[0.99811324 1.01338681 0.99202837 ... 1.00786872 1.0135691  0.98008548]
#   [1.02108278 0.98841925 0.99672546 ... 0.99593953 0.94115284 0.98499736]
#   [0.95879789 0.99988713 0.96541269 ... 0.9918749  0.99459226 1.04906766]
#   ...
#   [1.01554019 0.99758999 0.9814059  ... 1.03576708 1.02839971 1.02368563]
#   [1.03032947 0.99097826 0.96173258 ... 1.01484212 1.01941729 0.99643631]
#   [0.97182092 1.00752416 1.03392288 ... 0.95383049 1.00326274 1.00277857]]
#
#  ...
#
#  [[0.95753991 1.013145   0.98444479 ... 1.01052808 0.9991233  1.01320202]
#   [0.97750637 0.98859502 1.00533425 ... 0.99606267 0.99842209 0.99657323]
#   [1.00379933 0.97980947 1.01971354 ... 0.99658038 0.97038049 0.98071905]
#   ...
#   [1.01958247 0.96382255 0.9765531  ... 1.01432785 1.0016449  1.00938335]
#   [0.95952505 1.024951   0.98776621 ... 0.97341331 1.03148867 1.00985218]
#   [0.96684293 1.00081983 1.01775904 ... 0.99913403 1.04882635 1.00942125]]
#
#  [[0.99811324 0.98008548 1.0135691  ... 0.98944229 0.99202837 1.01338681]
#   [0.97182092 1.00277857 1.00326274 ... 1.01958864 1.03392288 1.00752416]
#   [1.03032947 0.99643631 1.01941729 ... 0.99591828 0.96173258 0.99097826]
#   ...
#   [0.97474407 1.01938151 0.98370164 ... 1.01579772 0.99977821 0.96715206]
#   [0.95879789 1.04906766 0.99459226 ... 0.9928252  0.96541269 0.99988713]
#   [1.02108278 0.98499736 0.94115284 ... 1.0042018  0.99672546 0.98841925]]
#
#  [[1.01598885 0.981747   1.01345623 ... 0.99008673 1.00399415 0.99841868]
#   [1.00200145 0.97942834 1.03613808 ... 0.96344899 0.97284631 0.98492376]
#   [1.00170404 0.97994453 0.97981913 ... 0.99178593 0.99335757 0.99763404]
#   ...
#   [0.97901519 1.01152941 0.99299289 ... 1.01283159 1.03544892 1.00139638]
#   [1.0108995  0.95454723 1.00477354 ... 0.97738059 0.97849204 0.93246254]
#   [0.99680672 1.00135148 1.01667582 ... 1.00068726 0.97508173 1.01854001]]] dimensionless

# %%
plt.figure(10, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufbarx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufbarx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
# Show the plot
plt.show()

plt.figure(11, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ugbarx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b')
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ugbarx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
# Show the plot
plt.show()

plt.figure(12, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_nfbarx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b')
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S nfbarx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
# Show the plot
plt.show()

plt.figure(13, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ngbarx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ngbarx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)
# Show the plot
plt.show()

# %%
plt.figure(14, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufbarx_nfbarx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufbarx_nfbarx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.)
plt.grid(True)
# Show the plot
plt.show()

plt.figure(15, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufbarx_ugbarx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufbarx_ugbarx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.)
plt.grid(True)
# Show the plot
plt.show()

plt.figure(16, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ugbarx_nfbarx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ugbarx_nfbarx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.)
plt.grid(True)
# Show the plot
plt.show()

# %%
##############################
nx = 64
ny = 2
nz = 2
temperature = 1e-5
alpha0 = 0.
##############################

plot_file_dir_S_rho = "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) \
            + "_size{:d}-{:d}-{:d}_continue/correlation_rho".format(nx, ny, nz)

ds = yt.load(plot_file_dir_S_rho)
box = ds.domain_dimensions
print(ds.field_list)
#profile_data_S_rho = ds.all_data()[("boxlib", "S_rho")].to_ndarray()
profile_data_S_rho = ds.covering_grid(
    level=0, left_edge=ds.domain_left_edge, dims=ds.domain_dimensions
)

S_rho_array = profile_data_S_rho["boxlib", "S_rho"]
#S_rho_array = profile_data_S_rho["boxlib", "struct_fact_rho_rho"]
#S_rho_array = profile_data_S_rho.reshape(box[0],box[1],box[2])
#print(S_rho_array.max())
nxh = box[0]//2
kx = 2*np.pi/box[0]*(np.linspace(0, nxh-1, nxh))
S_rho_array_kx = S_rho_array[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/cs2) # add 1 additional position
S_rho_array_kx_0_1 = S_rho_array[nxh%box[0]:(2*nxh-1)%box[0]+1,0,1]/(temperature/cs2) # add 1 additional position
S_rho_array_kx_1_0 = S_rho_array[nxh%box[0]:(2*nxh-1)%box[0]+1,1,0]/(temperature/cs2) # add 1 additional position
S_rho_array_kx_1_1 = S_rho_array[nxh%box[0]:(2*nxh-1)%box[0]+1,1,1]/(temperature/cs2) # add 1 additional position


# Plotting the data
plt.figure(figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_rho_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b')  # Create a line plot
#plt.plot(kx, S_rho_array_kx_0_1, label='[ky,kz]=[0,1]', marker='o', linestyle='', color='r')  # Create a line plot
#plt.plot(kx, S_rho_array_kx_1_0, label='[ky,kz]=[1,0]', marker='o', linestyle='', color='k')  # Create a line plot
#plt.plot(kx, S_rho_array_kx_1_1, label='[ky,kz]=[1,1]', marker='o', linestyle='', color='g')  # Create a line plot
plt.legend(title="Figure 1")
#ax.set_ylim(0, 2)  # Set y-axis range from -2 to 2

# Add labels and title
plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S rho vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title

# Add a legend
# Display the grid (optional)
plt.grid(True)
# Show the plot
plt.show()
plt.savefig('my_plot.png', dpi=300)
# Out:
# yt : [ERROR    ] 2025-02-21 15:08:33,529 None of the arguments provided to load() is a valid file
# yt : [ERROR    ] 2025-02-21 15:08:33,531 Please check that you have used a correct path
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-3-799c69842e51> in <module>
#      11             + "_size{:d}-{:d}-{:d}_continue/correlation_rho".format(nx, ny, nz)
#      12
# ---> 13 ds = yt.load(plot_file_dir_S_rho)
#      14 box = ds.domain_dimensions
#      15 print(ds.field_list)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/yt/convenience.py in load(*args, **kwargs)
#      74             mylog.error("None of the arguments provided to load() is a valid file")
#      75             mylog.error("Please check that you have used a correct path")
# ---> 76             raise YTOutputNotIdentified(args, kwargs)
#      77     for n, c in types_to_check.items():
#      78         if n is None: continue
#
# YTOutputNotIdentified: Supplied ('./data_mixture/lbm_data_shshan_alpha0_0.00_xi_1.0e-05_size64-2-2_continue/correlation_rho',) {}, but could not load!

# %%
##############         DENSITY         ################
nx = 16#32 #64
ny = 16#32 #2
nz = 16#32 #2
temperature = 1e-5
alpha0 = 0.
#######################################################
import numpy as np

#plot_file_rho_mean = "./data_mixture/rho_steps.txt"
#plot_file_phi_mean = "./data_mixture/phi_steps.txt" # 2 currently uptp 2500400

plot_file_hydrovs_root = ""
if temperature > 0:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}_continue/plt".format(nx,ny,nz)
else:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz)
folder_path = plot_file_hydrovs_root[:len(plot_file_hydrovs_root)-3]
plot_file_rho_mean = folder_path + "rho_steps.txt"
plot_file_phi_mean = folder_path + "phi_steps.txt"

rho_array = np.genfromtxt(plot_file_rho_mean, delimiter='\t', invalid_raise=False)
phi_array = np.genfromtxt(plot_file_phi_mean, delimiter='\t', invalid_raise=False)
step = np.arange(rho_array.shape[0])

step = np.arange(rho_array.shape[0])
plt.plot(step, rho_array, label="rho", color='r')
plt.plot(step, phi_array, label="phi", color='b')
plt.plot(step, rho_array + phi_array, label="rho_tot", color='k')
plt.legend(title="Figure density ~ steps")
plt.xlabel('Index')  # Label for x-axis
plt.ylabel('Y-values')  # Label for y-axis
plt.title('Plot of the Data')  # Title
plt.show()
# Out:
# /tmp/ipykernel_312815/1981177052.py:24: ConversionWarning: Some errors were detected !
#     Line #202 (got 2 columns instead of 1)
#   rho_array = np.genfromtxt(plot_file_rho_mean, delimiter='\t', invalid_raise=False)
# /tmp/ipykernel_312815/1981177052.py:25: ConversionWarning: Some errors were detected !
#     Line #202 (got 2 columns instead of 1)
#   phi_array = np.genfromtxt(plot_file_phi_mean, delimiter='\t', invalid_raise=False)

# %%
############    Generate mean density by given init steps & interval    ############################
step1 = 10000
step2 = 700000
plot_int = 5000 #10
temperature = 1e-5
alpha0 = 0.
cs2 = 1./3.
nx = 32
ny = 32
nz = 32
ncomp = 19  # nvel in LBM
###############################################################

Nframes = (step2 - step1)//plot_int + 1
density_ndarray = np.zeros((Nframes, 2, nx, ny, nz))

plot_file_hydrovs_root = ""
if temperature > 0:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}_continue/plt".format(nx,ny,nz)
else:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz)


# load in noise multifab of each frame into ndarray
for n in range(step1, step2+1, plot_int):
    plot_file_fnoise = plot_file_hydrovs_root + f"{n:07d}"
    ds0 = yt.load(plot_file_fnoise)
    hydrovs_data_frame = ds0.covering_grid(
    level=0, left_edge=ds0.domain_left_edge, dims=ds0.domain_dimensions)
    #density_ndarray[(n-step1)//plot_int, 0, :,:,:] = hydrovs_data_frame["boxlib", "rho"]
    #density_ndarray[(n-step1)//plot_int, 1, :,:,:] = hydrovs_data_frame["boxlib", "phi"]
    rho_array[(n-step1)//plot_int] = np.mean(hydrovs_data_frame["boxlib", "rho"])
    phi_array[(n-step1)//plot_int] = np.mean(hydrovs_data_frame["boxlib", "phi"])

# Open the file in append mode and save data
plot_file_rho = plot_file_hydrovs_root[:len(plot_file_hydrovs_root)-3] + "rho_steps.txt"
plot_file_phi = plot_file_hydrovs_root[:len(plot_file_hydrovs_root)-3] + "phi_steps.txt"
#print(plot_file_rho)

with open(plot_file_rho, "a") as f:
    np.savetxt(f, phi_array, delimiter="\t", fmt="%.6f")
    f.write("\t")
with open(plot_file_phi, "a") as f:
    np.savetxt(f, rho_array, delimiter="\t", fmt="%.6f")
    f.write("\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 29
#      27 for n in range(step1, step2+1, plot_int):
#      28     plot_file_fnoise = plot_file_hydrovs_root + f"{n:07d}"
# ---> 29     ds0 = yt.load(plot_file_fnoise)
#      30     hydrovs_data_frame = ds0.covering_grid(
#      31     level=0, left_edge=ds0.domain_left_edge, dims=ds0.domain_dimensions)
#      32     #density_ndarray[(n-step1)//plot_int, 0, :,:,:] = hydrovs_data_frame["boxlib", "rho"]
#      33     #density_ndarray[(n-step1)//plot_int, 1, :,:,:] = hydrovs_data_frame["boxlib", "phi"]
#
# File ~/anaconda3/lib/python3.12/site-packages/yt/_maintenance/deprecation.py:68, in future_positional_only.<locals>.outer.<locals>.inner(*args, **kwargs)
#      59     value = kwargs[name]
#      60     issue_deprecation_warning(
#      61         f"Using the {name!r} argument as keyword (on position {no}) "
#      62         "is deprecated. "
#    (...)
#      66         **depr_kwargs,
#      67     )
# ---> 68 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/yt/loaders.py:111, in load(fn, hint, *args, **kwargs)
#     108 # This will raise FileNotFoundError if the path isn't matched
#     109 # either in the current dir or yt.config.ytcfg['data_dir_directory']
#     110 if not fn.startswith("http"):
# --> 111     fn = str(lookup_on_disk_data(fn))
#     113 external_frontends = entry_points(group="yt.frontends")
#     115 # Ensure that external frontends are loaded
#
# File ~/anaconda3/lib/python3.12/site-packages/yt/sample_data/api.py:187, in lookup_on_disk_data(fn)
#     185         return alt_path
#     186     err_msg += f"\n(Also tried '{alt_path}')."
# --> 187 raise FileNotFoundError(err_msg)
#
# FileNotFoundError: No such file or directory: './data_mixture/lbm_data_shshan_alpha0_0.00_xi_1.0e-05_size32-32-32_continue/plt0010000'.

# %%
############    Generate mean density by looping over folder    ############################
import os
import re

temperature = 1e-5
alpha0 = 0.
cs2 = 1./3.
nx = 16#32
ny = 16#32
nz = 16#32
ncomp = 19  # nvel in LBM
###############################################################

plot_file_hydrovs_root = ""
if temperature > 0:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}_continue/plt".format(nx,ny,nz)
else:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz)



# Specify the folder path
folder_path = plot_file_hydrovs_root[:len(plot_file_hydrovs_root)-3]
rho_array = []
phi_array = []
pattern = r"^plt\d+$"

# Loop through all files in the folder
for filename in sorted(os.listdir(folder_path)):  # Ensure order
    file_path = os.path.join(folder_path, filename)
    #print(f"Opening: {file_path}")  
    if re.match(pattern, filename):
        file_path = os.path.join(folder_path, filename)
        ds0 = yt.load(file_path)
        hydrovs_data_frame = ds0.covering_grid(
        level=0, left_edge=ds0.domain_left_edge, dims=ds0.domain_dimensions)    
        rho_array.append(np.mean(hydrovs_data_frame["boxlib", "rho"]))
        phi_array.append(np.mean(hydrovs_data_frame["boxlib", "phi"]))
    
plot_file_rho = folder_path + "rho_steps.txt"
plot_file_phi = folder_path + "phi_steps.txt"
with open(plot_file_rho, "w") as f: # overwrite mode
    np.savetxt(f, phi_array, delimiter="\t", fmt="%.6f")
    f.write("\t")
with open(plot_file_phi, "w") as f:
    np.savetxt(f, rho_array, delimiter="\t", fmt="%.6f")
    f.write("\t")
# Out:
# yt : [INFO     ] 2025-03-30 19:37:41,585 Parameters: current_time              = 2000.0
# yt : [INFO     ] 2025-03-30 19:37:41,588 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:41,592 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:41,594 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:43,533 Parameters: current_time              = 4000.0
# yt : [INFO     ] 2025-03-30 19:37:43,534 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:43,535 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:43,536 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:43,759 Parameters: current_time              = 6000.0
# yt : [INFO     ] 2025-03-30 19:37:43,760 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:43,760 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:43,761 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:43,975 Parameters: current_time              = 8000.0
# yt : [INFO     ] 2025-03-30 19:37:43,975 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:43,976 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:43,977 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:44,201 Parameters: current_time              = 10000.0
# yt : [INFO     ] 2025-03-30 19:37:44,202 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:44,203 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:44,203 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:44,427 Parameters: current_time              = 12000.0
# yt : [INFO     ] 2025-03-30 19:37:44,428 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:44,430 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:44,431 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:44,702 Parameters: current_time              = 14000.0
# yt : [INFO     ] 2025-03-30 19:37:44,702 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:44,703 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:44,704 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:44,900 Parameters: current_time              = 16000.0
# yt : [INFO     ] 2025-03-30 19:37:44,901 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:44,901 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:44,902 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:45,037 Parameters: current_time              = 18000.0
# yt : [INFO     ] 2025-03-30 19:37:45,038 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:45,039 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:45,040 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:45,274 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2025-03-30 19:37:45,275 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:45,275 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:45,276 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:45,418 Parameters: current_time              = 22000.0
# yt : [INFO     ] 2025-03-30 19:37:45,419 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:45,420 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:45,420 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:45,571 Parameters: current_time              = 24000.0
# yt : [INFO     ] 2025-03-30 19:37:45,572 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:45,573 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:45,574 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:45,825 Parameters: current_time              = 26000.0
# yt : [INFO     ] 2025-03-30 19:37:45,826 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:45,828 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:45,829 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:46,282 Parameters: current_time              = 28000.0
# yt : [INFO     ] 2025-03-30 19:37:46,283 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:46,284 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:46,285 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:46,891 Parameters: current_time              = 30000.0
# yt : [INFO     ] 2025-03-30 19:37:46,893 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:46,896 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:46,901 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:47,276 Parameters: current_time              = 32000.0
# yt : [INFO     ] 2025-03-30 19:37:47,277 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:47,278 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:47,279 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:47,458 Parameters: current_time              = 34000.0
# yt : [INFO     ] 2025-03-30 19:37:47,459 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:47,460 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:47,461 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:47,649 Parameters: current_time              = 36000.0
# yt : [INFO     ] 2025-03-30 19:37:47,650 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:47,651 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:47,652 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:47,861 Parameters: current_time              = 38000.0
# yt : [INFO     ] 2025-03-30 19:37:47,861 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:47,862 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:47,863 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:48,070 Parameters: current_time              = 40000.0
# yt : [INFO     ] 2025-03-30 19:37:48,071 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:48,072 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:48,073 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:48,258 Parameters: current_time              = 42000.0
# yt : [INFO     ] 2025-03-30 19:37:48,260 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:48,261 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:48,263 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:48,429 Parameters: current_time              = 44000.0
# yt : [INFO     ] 2025-03-30 19:37:48,430 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:48,432 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:48,433 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:48,617 Parameters: current_time              = 46000.0
# yt : [INFO     ] 2025-03-30 19:37:48,618 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:48,619 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:48,620 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:48,778 Parameters: current_time              = 48000.0
# yt : [INFO     ] 2025-03-30 19:37:48,778 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:48,779 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:48,780 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:48,886 Parameters: current_time              = 50000.0
# yt : [INFO     ] 2025-03-30 19:37:48,886 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:48,887 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:48,887 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:49,005 Parameters: current_time              = 52000.0
# yt : [INFO     ] 2025-03-30 19:37:49,006 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:49,007 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:49,008 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:49,199 Parameters: current_time              = 54000.0
# yt : [INFO     ] 2025-03-30 19:37:49,200 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:49,200 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:49,202 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:49,505 Parameters: current_time              = 56000.0
# yt : [INFO     ] 2025-03-30 19:37:49,505 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:49,506 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:49,507 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:49,639 Parameters: current_time              = 58000.0
# yt : [INFO     ] 2025-03-30 19:37:49,641 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:49,642 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:49,643 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:49,764 Parameters: current_time              = 60000.0
# yt : [INFO     ] 2025-03-30 19:37:49,765 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:49,766 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:49,767 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:49,913 Parameters: current_time              = 62000.0
# yt : [INFO     ] 2025-03-30 19:37:49,914 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:49,915 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:49,915 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:50,010 Parameters: current_time              = 64000.0
# yt : [INFO     ] 2025-03-30 19:37:50,011 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:50,012 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:50,012 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:50,146 Parameters: current_time              = 66000.0
# yt : [INFO     ] 2025-03-30 19:37:50,147 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:50,148 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:50,149 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:50,280 Parameters: current_time              = 68000.0
# yt : [INFO     ] 2025-03-30 19:37:50,280 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:50,281 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:50,282 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:50,388 Parameters: current_time              = 70000.0
# yt : [INFO     ] 2025-03-30 19:37:50,389 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:50,389 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:50,390 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:50,489 Parameters: current_time              = 72000.0
# yt : [INFO     ] 2025-03-30 19:37:50,490 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:50,491 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:50,491 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:50,585 Parameters: current_time              = 74000.0
# yt : [INFO     ] 2025-03-30 19:37:50,586 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:50,586 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:50,587 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:50,696 Parameters: current_time              = 76000.0
# yt : [INFO     ] 2025-03-30 19:37:50,697 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:50,698 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:50,699 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:50,810 Parameters: current_time              = 78000.0
# yt : [INFO     ] 2025-03-30 19:37:50,810 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:50,811 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:50,811 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,039 Parameters: current_time              = 80000.0
# yt : [INFO     ] 2025-03-30 19:37:51,040 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,041 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,041 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,148 Parameters: current_time              = 82000.0
# yt : [INFO     ] 2025-03-30 19:37:51,149 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,150 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,151 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,267 Parameters: current_time              = 84000.0
# yt : [INFO     ] 2025-03-30 19:37:51,268 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,269 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,270 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,394 Parameters: current_time              = 86000.0
# yt : [INFO     ] 2025-03-30 19:37:51,395 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,395 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,396 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,507 Parameters: current_time              = 88000.0
# yt : [INFO     ] 2025-03-30 19:37:51,508 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,509 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,510 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,626 Parameters: current_time              = 90000.0
# yt : [INFO     ] 2025-03-30 19:37:51,627 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,627 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,628 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,735 Parameters: current_time              = 92000.0
# yt : [INFO     ] 2025-03-30 19:37:51,736 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,736 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,737 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,848 Parameters: current_time              = 94000.0
# yt : [INFO     ] 2025-03-30 19:37:51,849 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,849 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,850 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:51,943 Parameters: current_time              = 96000.0
# yt : [INFO     ] 2025-03-30 19:37:51,943 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:51,944 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:51,945 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:52,041 Parameters: current_time              = 98000.0
# yt : [INFO     ] 2025-03-30 19:37:52,042 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:52,042 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:52,043 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:52,132 Parameters: current_time              = 100000.0
# yt : [INFO     ] 2025-03-30 19:37:52,132 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:52,133 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:52,134 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:52,235 Parameters: current_time              = 102000.0
# yt : [INFO     ] 2025-03-30 19:37:52,236 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:52,236 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:52,237 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:52,483 Parameters: current_time              = 104000.0
# yt : [INFO     ] 2025-03-30 19:37:52,485 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:52,486 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:52,488 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:52,603 Parameters: current_time              = 106000.0
# yt : [INFO     ] 2025-03-30 19:37:52,604 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:52,605 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:52,605 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:52,703 Parameters: current_time              = 108000.0
# yt : [INFO     ] 2025-03-30 19:37:52,704 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:52,705 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:52,706 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:52,803 Parameters: current_time              = 110000.0
# yt : [INFO     ] 2025-03-30 19:37:52,803 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:52,804 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:52,805 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:52,900 Parameters: current_time              = 112000.0
# yt : [INFO     ] 2025-03-30 19:37:52,901 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:52,901 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:52,902 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:53,008 Parameters: current_time              = 114000.0
# yt : [INFO     ] 2025-03-30 19:37:53,009 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:53,010 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:53,010 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:53,130 Parameters: current_time              = 116000.0
# yt : [INFO     ] 2025-03-30 19:37:53,131 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:53,131 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:53,132 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:53,271 Parameters: current_time              = 118000.0
# yt : [INFO     ] 2025-03-30 19:37:53,273 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:53,273 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:53,274 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:53,422 Parameters: current_time              = 120000.0
# yt : [INFO     ] 2025-03-30 19:37:53,423 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:53,423 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:53,424 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:53,558 Parameters: current_time              = 122000.0
# yt : [INFO     ] 2025-03-30 19:37:53,559 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:53,560 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:53,561 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:53,697 Parameters: current_time              = 124000.0
# yt : [INFO     ] 2025-03-30 19:37:53,697 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:53,698 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:53,698 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:53,803 Parameters: current_time              = 126000.0
# yt : [INFO     ] 2025-03-30 19:37:53,804 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:53,804 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:53,805 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:53,944 Parameters: current_time              = 128000.0
# yt : [INFO     ] 2025-03-30 19:37:53,945 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:53,946 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:53,947 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:54,173 Parameters: current_time              = 130000.0
# yt : [INFO     ] 2025-03-30 19:37:54,174 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:54,175 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:54,176 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:54,300 Parameters: current_time              = 132000.0
# yt : [INFO     ] 2025-03-30 19:37:54,300 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:54,301 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:54,301 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:54,407 Parameters: current_time              = 134000.0
# yt : [INFO     ] 2025-03-30 19:37:54,408 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:54,408 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:54,409 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:54,522 Parameters: current_time              = 136000.0
# yt : [INFO     ] 2025-03-30 19:37:54,523 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:54,524 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:54,525 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:54,622 Parameters: current_time              = 138000.0
# yt : [INFO     ] 2025-03-30 19:37:54,623 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:54,623 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:54,624 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:54,728 Parameters: current_time              = 140000.0
# yt : [INFO     ] 2025-03-30 19:37:54,729 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:54,730 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:54,730 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:54,822 Parameters: current_time              = 142000.0
# yt : [INFO     ] 2025-03-30 19:37:54,823 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:54,823 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:54,824 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:54,916 Parameters: current_time              = 144000.0
# yt : [INFO     ] 2025-03-30 19:37:54,916 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:54,917 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:54,918 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:55,020 Parameters: current_time              = 146000.0
# yt : [INFO     ] 2025-03-30 19:37:55,021 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:55,021 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:55,023 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:55,120 Parameters: current_time              = 148000.0
# yt : [INFO     ] 2025-03-30 19:37:55,120 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:55,121 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:55,122 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:55,225 Parameters: current_time              = 150000.0
# yt : [INFO     ] 2025-03-30 19:37:55,225 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:55,226 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:55,227 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:55,326 Parameters: current_time              = 152000.0
# yt : [INFO     ] 2025-03-30 19:37:55,327 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:55,329 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:55,330 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:55,534 Parameters: current_time              = 154000.0
# yt : [INFO     ] 2025-03-30 19:37:55,535 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:55,535 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:55,536 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:55,649 Parameters: current_time              = 156000.0
# yt : [INFO     ] 2025-03-30 19:37:55,650 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:55,650 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:55,651 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:55,770 Parameters: current_time              = 158000.0
# yt : [INFO     ] 2025-03-30 19:37:55,771 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:55,772 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:55,773 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:55,931 Parameters: current_time              = 160000.0
# yt : [INFO     ] 2025-03-30 19:37:55,932 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:55,934 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:55,935 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:56,087 Parameters: current_time              = 162000.0
# yt : [INFO     ] 2025-03-30 19:37:56,088 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:56,089 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:56,089 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:56,247 Parameters: current_time              = 164000.0
# yt : [INFO     ] 2025-03-30 19:37:56,247 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:56,249 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:56,250 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:56,409 Parameters: current_time              = 166000.0
# yt : [INFO     ] 2025-03-30 19:37:56,410 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:56,411 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:56,412 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:56,552 Parameters: current_time              = 168000.0
# yt : [INFO     ] 2025-03-30 19:37:56,553 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:56,554 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:56,554 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:56,683 Parameters: current_time              = 170000.0
# yt : [INFO     ] 2025-03-30 19:37:56,685 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:56,685 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:56,686 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:56,841 Parameters: current_time              = 172000.0
# yt : [INFO     ] 2025-03-30 19:37:56,843 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:56,844 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:56,845 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:56,988 Parameters: current_time              = 174000.0
# yt : [INFO     ] 2025-03-30 19:37:56,989 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:56,989 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:56,990 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:57,114 Parameters: current_time              = 176000.0
# yt : [INFO     ] 2025-03-30 19:37:57,114 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:57,115 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:57,115 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:57,378 Parameters: current_time              = 178000.0
# yt : [INFO     ] 2025-03-30 19:37:57,379 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:57,380 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:57,382 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:57,515 Parameters: current_time              = 180000.0
# yt : [INFO     ] 2025-03-30 19:37:57,516 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:57,517 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:57,518 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:57,670 Parameters: current_time              = 182000.0
# yt : [INFO     ] 2025-03-30 19:37:57,671 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:57,672 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:57,673 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:57,828 Parameters: current_time              = 184000.0
# yt : [INFO     ] 2025-03-30 19:37:57,828 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:57,829 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:57,829 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:57,945 Parameters: current_time              = 186000.0
# yt : [INFO     ] 2025-03-30 19:37:57,946 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:57,947 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:57,947 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:58,059 Parameters: current_time              = 188000.0
# yt : [INFO     ] 2025-03-30 19:37:58,059 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:58,060 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:58,061 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:58,183 Parameters: current_time              = 190000.0
# yt : [INFO     ] 2025-03-30 19:37:58,183 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:58,184 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:58,184 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:58,297 Parameters: current_time              = 192000.0
# yt : [INFO     ] 2025-03-30 19:37:58,298 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:58,298 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:58,299 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:58,415 Parameters: current_time              = 194000.0
# yt : [INFO     ] 2025-03-30 19:37:58,416 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:58,416 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:58,417 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:58,535 Parameters: current_time              = 196000.0
# yt : [INFO     ] 2025-03-30 19:37:58,536 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:58,537 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:58,538 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:58,732 Parameters: current_time              = 198000.0
# yt : [INFO     ] 2025-03-30 19:37:58,733 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:58,734 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:58,735 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:58,899 Parameters: current_time              = 200000.0
# yt : [INFO     ] 2025-03-30 19:37:58,900 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:58,901 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:58,903 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:59,050 Parameters: current_time              = 202000.0
# yt : [INFO     ] 2025-03-30 19:37:59,051 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:59,052 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:59,053 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:59,296 Parameters: current_time              = 204000.0
# yt : [INFO     ] 2025-03-30 19:37:59,296 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:59,297 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:59,298 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:59,458 Parameters: current_time              = 206000.0
# yt : [INFO     ] 2025-03-30 19:37:59,458 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:59,459 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:59,460 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:37:59,762 Parameters: current_time              = 208000.0
# yt : [INFO     ] 2025-03-30 19:37:59,764 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:37:59,765 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:37:59,767 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:00,125 Parameters: current_time              = 210000.0
# yt : [INFO     ] 2025-03-30 19:38:00,127 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:00,129 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:00,131 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:00,416 Parameters: current_time              = 212000.0
# yt : [INFO     ] 2025-03-30 19:38:00,417 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:00,418 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:00,419 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:00,712 Parameters: current_time              = 214000.0
# yt : [INFO     ] 2025-03-30 19:38:00,713 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:00,715 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:00,717 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:00,999 Parameters: current_time              = 216000.0
# yt : [INFO     ] 2025-03-30 19:38:01,000 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:01,002 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:01,003 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:01,300 Parameters: current_time              = 218000.0
# yt : [INFO     ] 2025-03-30 19:38:01,302 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:01,304 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:01,306 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:01,622 Parameters: current_time              = 220000.0
# yt : [INFO     ] 2025-03-30 19:38:01,628 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:01,632 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:01,633 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:01,796 Parameters: current_time              = 222000.0
# yt : [INFO     ] 2025-03-30 19:38:01,797 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:01,798 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:01,799 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:01,968 Parameters: current_time              = 224000.0
# yt : [INFO     ] 2025-03-30 19:38:01,969 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:01,970 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:01,972 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:02,146 Parameters: current_time              = 226000.0
# yt : [INFO     ] 2025-03-30 19:38:02,147 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:02,147 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:02,148 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:02,466 Parameters: current_time              = 228000.0
# yt : [INFO     ] 2025-03-30 19:38:02,467 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:02,468 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:02,469 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:02,607 Parameters: current_time              = 230000.0
# yt : [INFO     ] 2025-03-30 19:38:02,608 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:02,609 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:02,611 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:02,756 Parameters: current_time              = 232000.0
# yt : [INFO     ] 2025-03-30 19:38:02,757 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:02,758 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:02,759 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:02,886 Parameters: current_time              = 234000.0
# yt : [INFO     ] 2025-03-30 19:38:02,887 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:02,888 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:02,889 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:03,104 Parameters: current_time              = 236000.0
# yt : [INFO     ] 2025-03-30 19:38:03,105 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:03,106 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:03,107 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:03,249 Parameters: current_time              = 238000.0
# yt : [INFO     ] 2025-03-30 19:38:03,250 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:03,251 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:03,252 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:03,381 Parameters: current_time              = 240000.0
# yt : [INFO     ] 2025-03-30 19:38:03,382 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:03,382 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:03,383 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:03,520 Parameters: current_time              = 242000.0
# yt : [INFO     ] 2025-03-30 19:38:03,521 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:03,521 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:03,522 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:03,680 Parameters: current_time              = 244000.0
# yt : [INFO     ] 2025-03-30 19:38:03,681 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:03,682 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:03,684 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:03,857 Parameters: current_time              = 246000.0
# yt : [INFO     ] 2025-03-30 19:38:03,858 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:03,859 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:03,860 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:04,015 Parameters: current_time              = 248000.0
# yt : [INFO     ] 2025-03-30 19:38:04,016 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:04,017 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:04,018 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:04,312 Parameters: current_time              = 250000.0
# yt : [INFO     ] 2025-03-30 19:38:04,313 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:04,314 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:04,315 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:04,752 Parameters: current_time              = 252000.0
# yt : [INFO     ] 2025-03-30 19:38:04,753 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:04,754 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:04,755 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:04,912 Parameters: current_time              = 254000.0
# yt : [INFO     ] 2025-03-30 19:38:04,913 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:04,914 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:04,915 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:05,075 Parameters: current_time              = 256000.0
# yt : [INFO     ] 2025-03-30 19:38:05,076 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:05,077 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:05,078 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:05,220 Parameters: current_time              = 258000.0
# yt : [INFO     ] 2025-03-30 19:38:05,221 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:05,222 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:05,223 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:05,386 Parameters: current_time              = 260000.0
# yt : [INFO     ] 2025-03-30 19:38:05,387 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:05,388 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:05,389 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:05,538 Parameters: current_time              = 262000.0
# yt : [INFO     ] 2025-03-30 19:38:05,538 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:05,539 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:05,540 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:05,680 Parameters: current_time              = 264000.0
# ...
# yt : [INFO     ] 2025-03-30 19:38:09,159 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:09,160 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:09,270 Parameters: current_time              = 318000.0
# yt : [INFO     ] 2025-03-30 19:38:09,271 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:09,271 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:09,272 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:09,392 Parameters: current_time              = 320000.0
# yt : [INFO     ] 2025-03-30 19:38:09,392 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:09,393 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:09,394 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:09,503 Parameters: current_time              = 322000.0
# yt : [INFO     ] 2025-03-30 19:38:09,504 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:09,505 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:09,506 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:09,608 Parameters: current_time              = 324000.0
# yt : [INFO     ] 2025-03-30 19:38:09,608 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:09,609 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:09,610 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:09,800 Parameters: current_time              = 326000.0
# yt : [INFO     ] 2025-03-30 19:38:09,800 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:09,801 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:09,802 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:09,931 Parameters: current_time              = 328000.0
# yt : [INFO     ] 2025-03-30 19:38:09,932 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:09,932 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:09,933 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:10,049 Parameters: current_time              = 330000.0
# yt : [INFO     ] 2025-03-30 19:38:10,050 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:10,051 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:10,052 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:10,176 Parameters: current_time              = 332000.0
# yt : [INFO     ] 2025-03-30 19:38:10,176 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:10,177 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:10,178 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:10,301 Parameters: current_time              = 334000.0
# yt : [INFO     ] 2025-03-30 19:38:10,301 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:10,302 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:10,303 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:10,429 Parameters: current_time              = 336000.0
# yt : [INFO     ] 2025-03-30 19:38:10,430 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:10,431 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:10,432 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:10,576 Parameters: current_time              = 338000.0
# yt : [INFO     ] 2025-03-30 19:38:10,577 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:10,577 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:10,578 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:10,739 Parameters: current_time              = 340000.0
# yt : [INFO     ] 2025-03-30 19:38:10,740 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:10,741 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:10,742 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:10,868 Parameters: current_time              = 342000.0
# yt : [INFO     ] 2025-03-30 19:38:10,869 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:10,870 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:10,870 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:10,989 Parameters: current_time              = 344000.0
# yt : [INFO     ] 2025-03-30 19:38:10,990 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:10,992 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:10,992 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:11,122 Parameters: current_time              = 346000.0
# yt : [INFO     ] 2025-03-30 19:38:11,123 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:11,124 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:11,125 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:11,248 Parameters: current_time              = 348000.0
# yt : [INFO     ] 2025-03-30 19:38:11,249 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:11,250 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:11,251 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:11,393 Parameters: current_time              = 350000.0
# yt : [INFO     ] 2025-03-30 19:38:11,394 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:11,395 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:11,395 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:11,633 Parameters: current_time              = 352000.0
# yt : [INFO     ] 2025-03-30 19:38:11,634 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:11,634 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:11,635 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:11,784 Parameters: current_time              = 354000.0
# yt : [INFO     ] 2025-03-30 19:38:11,785 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:11,786 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:11,787 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:11,905 Parameters: current_time              = 356000.0
# yt : [INFO     ] 2025-03-30 19:38:11,906 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:11,907 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:11,907 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:12,016 Parameters: current_time              = 358000.0
# yt : [INFO     ] 2025-03-30 19:38:12,016 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:12,017 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:12,018 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:12,198 Parameters: current_time              = 360000.0
# yt : [INFO     ] 2025-03-30 19:38:12,199 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:12,201 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:12,202 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:12,369 Parameters: current_time              = 362000.0
# yt : [INFO     ] 2025-03-30 19:38:12,370 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:12,371 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:12,371 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:12,492 Parameters: current_time              = 364000.0
# yt : [INFO     ] 2025-03-30 19:38:12,493 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:12,493 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:12,494 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:12,608 Parameters: current_time              = 366000.0
# yt : [INFO     ] 2025-03-30 19:38:12,609 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:12,610 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:12,610 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:12,725 Parameters: current_time              = 368000.0
# yt : [INFO     ] 2025-03-30 19:38:12,726 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:12,727 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:12,727 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:12,840 Parameters: current_time              = 370000.0
# yt : [INFO     ] 2025-03-30 19:38:12,842 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:12,843 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:12,844 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:12,987 Parameters: current_time              = 372000.0
# yt : [INFO     ] 2025-03-30 19:38:12,990 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:12,991 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:12,993 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:13,139 Parameters: current_time              = 374000.0
# yt : [INFO     ] 2025-03-30 19:38:13,141 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:13,142 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:13,144 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:13,408 Parameters: current_time              = 376000.0
# yt : [INFO     ] 2025-03-30 19:38:13,409 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:13,411 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:13,413 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:13,804 Parameters: current_time              = 378000.0
# yt : [INFO     ] 2025-03-30 19:38:13,805 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:13,806 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:13,807 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:13,954 Parameters: current_time              = 380000.0
# yt : [INFO     ] 2025-03-30 19:38:13,955 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:13,955 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:13,956 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:14,122 Parameters: current_time              = 382000.0
# yt : [INFO     ] 2025-03-30 19:38:14,123 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:14,124 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:14,126 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:14,308 Parameters: current_time              = 384000.0
# yt : [INFO     ] 2025-03-30 19:38:14,309 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:14,310 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:14,312 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:14,484 Parameters: current_time              = 386000.0
# yt : [INFO     ] 2025-03-30 19:38:14,485 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:14,486 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:14,487 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:14,638 Parameters: current_time              = 388000.0
# yt : [INFO     ] 2025-03-30 19:38:14,638 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:14,639 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:14,640 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:14,769 Parameters: current_time              = 390000.0
# yt : [INFO     ] 2025-03-30 19:38:14,770 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:14,771 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:14,772 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:14,919 Parameters: current_time              = 392000.0
# yt : [INFO     ] 2025-03-30 19:38:14,920 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:14,921 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:14,922 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:15,071 Parameters: current_time              = 394000.0
# yt : [INFO     ] 2025-03-30 19:38:15,072 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:15,073 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:15,073 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:15,228 Parameters: current_time              = 396000.0
# yt : [INFO     ] 2025-03-30 19:38:15,229 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:15,230 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:15,231 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:15,391 Parameters: current_time              = 398000.0
# yt : [INFO     ] 2025-03-30 19:38:15,392 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:15,393 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:15,394 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:15,557 Parameters: current_time              = 400000.0
# yt : [INFO     ] 2025-03-30 19:38:15,558 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:15,559 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:15,559 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-30 19:38:15,793 Parameters: current_time              = 400400.0
# yt : [INFO     ] 2025-03-30 19:38:15,794 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-03-30 19:38:15,795 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-30 19:38:15,796 Parameters: domain_right_edge         = [1. 1. 1.]
